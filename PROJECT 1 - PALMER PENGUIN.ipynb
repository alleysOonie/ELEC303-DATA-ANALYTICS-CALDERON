# %% [markdown]
# <h1> Palmer Penguin Data Analytics</h1> <hr>
# <h3> Analyst: Nichole Allyson Calderon</h3>

# %% [markdown]
# <p> Importing dataset to Jupyter Notebook </p>
# <p> Converting dataset to dataframe </p>
# <ul><strong> Requirements </strong>
#     <li> Name of the dataframe </li>
#     <li> Source</li>
# </ul>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <p> Importing dataset to Jupyter notebook</p>
# <p> Converting dataset to dataframe</p>
# <ul> <strong> Requirements </strong>
#     <li> Name of the dataframe</li>
#     <li> Source </li>
# </ul>

# %%
penguins = pd.read_csv('datasets\\penguins.csv')

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
adelie_df = penguins[penguins['species'] == 'Adelie']

# %%
adelie_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
chinstrap_df = penguins[penguins['species'] == 'Chinstrap']

# %%
chinstrap_df
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
gentoo_df = penguins[penguins['species'] == 'Gentoo']

# %%
gentoo_df
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152  Gentoo  Biscoe            46.1           13.2              211.0
# 153  Gentoo  Biscoe            50.0           16.3              230.0
# 154  Gentoo  Biscoe            48.7           14.1              210.0
# 155  Gentoo  Biscoe            50.0           15.2              218.0
# 156  Gentoo  Biscoe            47.6           14.5              215.0
# ..      ...     ...             ...            ...                ...
# 271  Gentoo  Biscoe             NaN            NaN                NaN
# 272  Gentoo  Biscoe            46.8           14.3              215.0
# 273  Gentoo  Biscoe            50.4           15.7              222.0
# 274  Gentoo  Biscoe            45.2           14.8              212.0
# 275  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 152       4500.0  female  2007
# 153       5700.0    male  2007
# ...

# %%
penguins[penguins['body_mass_g'] >= 4000]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 7       Adelie  Torgersen            39.2           19.6              195.0
# 9       Adelie  Torgersen            42.0           20.2              190.0
# 14      Adelie  Torgersen            34.6           21.1              198.0
# 17      Adelie  Torgersen            42.5           20.7              197.0
# 19      Adelie  Torgersen            46.0           21.5              194.0
# ..         ...        ...             ...            ...                ...
# 323  Chinstrap      Dream            49.0           19.6              212.0
# 329  Chinstrap      Dream            50.7           19.7              203.0
# 333  Chinstrap      Dream            49.3           19.9              203.0
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
#
#      body_mass_g   sex  year
# ...

# %%
(penguins['species'] == 'Chinstrap') & (penguins['body_mass_g'] >= 4000)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342     True
# 343    False
# Length: 344, dtype: bool

# %%
chinstrap_heavy = (penguins['species'] == 'Chinstrap') & (penguins['body_mass_g'] >= 4000)

# %%
chinstrap_heavy
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342     True
# 343    False
# Length: 344, dtype: bool

# %%
chinstrap_heavy.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 344 entries, 0 to 343
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 344 non-null    bool
# dtypes: bool(1)
# memory usage: 476.0 bytes

# %%
penguins[penguins['sex'] >= 'female']
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
(penguins['species'] == 'Chinstrap') & (penguins['sex'] >= 'female')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Length: 344, dtype: bool

# %%
penguins[(penguins['species'] == 'Chinstrap') & (penguins['sex'] >= 'female')]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
penguins[penguins['sex'] >= 'male']
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# 7       Adelie  Torgersen            39.2           19.6              195.0
# 13      Adelie  Torgersen            38.6           21.2              191.0
# 14      Adelie  Torgersen            34.6           21.1              198.0
# ..         ...        ...             ...            ...                ...
# 334  Chinstrap      Dream            50.2           18.8              202.0
# 336  Chinstrap      Dream            51.9           19.5              206.0
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
#
#      body_mass_g   sex  year
# ...

# %%
penguins[(penguins['species'] == 'Chinstrap') & (penguins['sex'] >= 'male')]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# 283  Chinstrap  Dream            51.3           18.2              197.0
# 285  Chinstrap  Dream            51.3           19.9              198.0
# 287  Chinstrap  Dream            51.7           20.3              194.0
# 289  Chinstrap  Dream            52.0           18.1              201.0
# 291  Chinstrap  Dream            50.5           19.6              201.0
# 292  Chinstrap  Dream            50.3           20.0              197.0
# 295  Chinstrap  Dream            49.2           18.2              195.0
# 297  Chinstrap  Dream            48.5           17.5              191.0
# 299  Chinstrap  Dream            50.6           19.4              193.0
# ...

# %%
penguins['sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3         NaN
# 4      female
#         ...
# 339      male
# 340    female
# 341      male
# 342      male
# 343    female
# Name: sex, Length: 344, dtype: object

# %%
penguins['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
penguins['sex'] = penguins['sex'].fillna(penguins['sex'].mode()[0])

# %%
penguins['bill_depth_mm']
# Out:
# 0      18.7
# 1      17.4
# 2      18.0
# 3       NaN
# 4      19.3
#        ...
# 339    19.8
# 340    18.1
# 341    18.2
# 342    19.0
# 343    18.7
# Name: bill_depth_mm, Length: 344, dtype: float64

# %%
penguins['bill_depth_mm'].mean()
# Out:
# np.float64(17.151169590643274)

# %%
penguins['bill_depth_mm'] = penguins['bill_depth_mm'].fillna(penguins['bill_depth_mm'].mean())

# %%
penguins['flipper_length_mm']
# Out:
# 0      181.0
# 1      186.0
# 2      195.0
# 3        NaN
# 4      193.0
#        ...
# 339    207.0
# 340    202.0
# 341    193.0
# 342    210.0
# 343    198.0
# Name: flipper_length_mm, Length: 344, dtype: float64

# %%
penguins['flipper_length_mm'].mean()
# Out:
# np.float64(200.91520467836258)

# %%
penguins['flipper_length_mm'] = penguins['flipper_length_mm'].fillna(penguins['flipper_length_mm'].mean())

# %%
penguins['bill_length_mm']
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339    55.8
# 340    43.5
# 341    49.6
# 342    50.8
# 343    50.2
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
penguins['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
penguins['bill_length_mm'] = penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())

# %%
penguins['body_mass_g']
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 344, dtype: float64

# %%
penguins['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
penguins['body_mass_g'] = penguins['body_mass_g'].fillna(penguins['body_mass_g'].mean())

# %%
penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
penguins['species'] = penguins['species'].astype('category')
penguins['year'] = penguins['year'].astype('category')
penguins['island'] = penguins['island'].astype('category')
penguins['sex'] = penguins['sex'].astype('category')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    category
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      344 non-null    float64
#  4   flipper_length_mm  344 non-null    float64
#  5   body_mass_g        344 non-null    float64
#  6   sex                344 non-null    category
#  7   year               344 non-null    category
# dtypes: category(4), float64(4)
# memory usage: 12.7 KB

# %% [markdown]
# <h1> Exploratory Data Analytics (EDA) </h1>

# %% [markdown]
# <h1> 1. Which species has the longest flipper length in mm? </h1>

# %%
chinstrap_df['flipper_length_mm'].mean()
# Out:
# np.float64(195.8235294117647)

# %%
adelie_df['flipper_length_mm'].mean()
# Out:
# np.float64(189.95364238410596)

# %%
gentoo_df['flipper_length_mm'].mean()
# Out:
# np.float64(217.1869918699187)

# %% [markdown]
# <h3> INSIGHT #1 </h3>
# <h4> The species that has the longest flippers is the GENTOO penguin. </h4>

# %% [markdown]
# <h1> 2. Which species has the shortest bill length in mm? </h1>

# %%
chinstrap_df['bill_length_mm'].mean()
# Out:
# np.float64(48.83382352941177)

# %%
adelie_df['bill_length_mm'].mean()
# Out:
# np.float64(38.79139072847682)

# %%
gentoo_df['bill_length_mm'].mean()
# Out:
# np.float64(47.50487804878048)

# %% [markdown]
# <h3> INSIGHT #2 </h3>
# <h4> Among the 3 species, CHINSTRAP penguin has the shortest bill lenght. </h4>

# %% [markdown]
# <h1> 3. Which of the three species has the largest population? </h1>

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# <h3> INSIGHT #3 </h3>
# <h4> In the 3 species of the penguin, ADELIE has the largest population. </h4>

# %% [markdown]
# <h1> 4. Which island has the most penguins? </h1>

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %% [markdown]
# <h3> INSIGHT #4 </h3>
# <h3> Biscoe Island has the most penguins, followed by Dream Island, while Torgersen has the least. </h3>

# %% [markdown]
# <H1> 5. Which island has the heaviest average penguin weight? </H1>

# %%
biscoe = penguins[penguins['island'] == 'Biscoe']['body_mass_g'].mean()

# %%
biscoe
# Out:
# np.float64(4712.95687134503)

# %%
dream = penguins[penguins['island'] == 'Dream']['body_mass_g'].mean()

# %%
dream
# Out:
# np.float64(3712.9032258064517)

# %%
torgersen = penguins[penguins['island'] == 'Torgersen']['body_mass_g'].mean()

# %%
torgersen
# Out:
# np.float64(3715.8991228070176)

# %% [markdown]
# <h3> INSIGHT #5 </h3>
# <H3> Biscoe Island penguins are the heaviest on average compared to Dream and Torgersen. </H3>

# %% [markdown]
# <H1> 6. How many penguins are there per species? </H1>

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# <h3> INSIGHT #6 </h3>
# <H3> Adelie penguins are the most numerous, followed by Gentoo, while Chinstrap has the least. </H3>

# %% [markdown]
# <H1> 7. Is there a difference in bill depth between Adelie and Gentoo penguins? </H1>

# %%
adelie = penguins[penguins["species"] == "Adelie"]["bill_depth_mm"]

# %%
adelie
# Out:
# 0      18.70000
# 1      17.40000
# 2      18.00000
# 3      17.15117
# 4      19.30000
#          ...
# 147    18.40000
# 148    17.80000
# 149    18.10000
# 150    17.10000
# 151    18.50000
# Name: bill_depth_mm, Length: 152, dtype: float64

# %%
gentoo = penguins[penguins["species"] == "Gentoo"]["bill_depth_mm"]

# %%
gentoo
# Out:
# 152    13.20000
# 153    16.30000
# 154    14.10000
# 155    15.20000
# 156    14.50000
#          ...
# 271    17.15117
# 272    14.30000
# 273    15.70000
# 274    14.80000
# 275    16.10000
# Name: bill_depth_mm, Length: 124, dtype: float64

# %% [markdown]
# <h3> INSIGHT #7</h3>
# <h3> Yes, there is a difference in bill depth between Adelie and Gentoo penguins. </h3>

# %% [markdown]
# <h1> 8. Is there a correlation between flipper length and body mass? </h1>

# %%
penguins['flipper_length_mm'].corr(penguins['body_mass_g'])
# Out:
# np.float64(0.8712017673060114)

# %% [markdown]
# <h3> INSIGHT #8 </h3>
# <h3> Yes, there's a positive correlation between flipper length and body mass, meaning penguins with longer flippers tend to be heavier.</h3>

# %% [markdown]
# <h1> 9. Do heavier penguins tend to have longer bills? </h1>

# %%
penguins['body_mass_g'].corr(penguins['bill_length_mm'])
# Out:
# np.float64(0.5951098244376305)

# %% [markdown]
# <H3> INSIGHT #9 </H3>
# <H3> Heavier penguins do not always have longer bills.</H3>

# %% [markdown]
# <H1> 10. Which species shows the strongest correlation between bill length and flipper length? </H1>

# %%
penguins[penguins["species"]=="Adelie"]["bill_length_mm"].corr(penguins[penguins["species"]=="Adelie"]["flipper_length_mm"])
# Out:
# np.float64(0.33983313631360895)

# %%
penguins[penguins["species"]=="Gentoo"]["bill_length_mm"].corr(penguins[penguins["species"]=="Gentoo"]["flipper_length_mm"])
# Out:
# np.float64(0.6643559408953931)

# %%
penguins[penguins["species"]=="Chinstrap"]["bill_length_mm"].corr(penguins[penguins["species"]=="Chinstrap"]["flipper_length_mm"])
# Out:
# np.float64(0.4716072789779736)

# %% [markdown]
# <h3> INSIGHT #10</h3>
# <H3> Gentoo penguins have the strongest correlation between bill length and flipper length. </H3>

# %% [markdown]
# <h1> 11. Which island has penguins with the longest average flipper length? </h1>

# %%
 penguins[penguins["island"]=="Torgersen"]["flipper_length_mm"].mean()
# Out:
# np.float64(191.38298470535312)

# %%
penguins[penguins["island"]=="Biscoe"]["flipper_length_mm"].mean()
# Out:
# np.float64(209.65425717070454)

# %%
penguins[penguins["island"]=="Dream"]["flipper_length_mm"].mean()
# Out:
# np.float64(193.07258064516128)

# %% [markdown]
# <h3> INSIGHT #11 </h3>
# <H3> Penguins from Biscoe Island have the longest average flipper length. </H3>

# %% [markdown]
# <h1> 12. Is there a correlation between bill length and bill depth? </h1>

# %%
penguins["bill_length_mm"].corr(penguins["bill_depth_mm"])
# Out:
# np.float64(-0.23505287035553282)

# %% [markdown]
# <h3> INSIGHT #12 </h3>
# <H3> Penguins with longer bills usually have shallower bills, while shorter bills are often deeper. </H3>

# %% [markdown]
# <h1> 13. Do male penguins have longer flippers than female penguins? </h1>

# %%
penguins[penguins.sex =="male"].flipper_length_mm.mean()
# Out:
# np.float64(204.18899670031692)

# %%
penguins[penguins.sex =="female"].flipper_length_mm.mean()
# Out:
# np.float64(197.36363636363637)

# %% [markdown]
# <H3> INSIGHT #13 </H3>
# <H3> Male penguins have longer flippers on average than female penguins. </H3>
