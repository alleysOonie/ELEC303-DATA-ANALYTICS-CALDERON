# %% [markdown]
# <h1> <strong>Chicago 2001 Present Data Analytics</strong></h1> <hr>
# <h3> Analyst: Nichole Allyson D. Calderon</h3>

# %% [markdown]
# <h3> <strong> Libraries </strong> </h3>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h3> <strong> Importing Data Set </strong></h3>

# %%
chicago = pd.read_csv('datasets\\chicago_2001_present.csv')
# Out:
# C:\Users\For All\AppData\Local\Temp\ipykernel_24824\13257833.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   chicago = pd.read_csv('datasets\\chicago_2001_present.csv')

# %%
chicago
# Out:
#                ID Case Number                    Date  \
# 0        13311263    JG503434  07/29/2022 03:39:00 AM
# 1        13053066    JG103252  01/03/2023 04:44:00 PM
# 2        12131221    JD327000  08/10/2020 09:45:00 AM
# 3        11227634    JB147599  08/26/2017 10:00:00 AM
# 4        13203321    JG415333  09/06/2023 05:00:00 PM
# ...           ...         ...                     ...
# 8410193  13973682    JJ422722  09/20/2025 09:30:00 PM
# 8410194  13973492    JJ422488  09/20/2025 11:30:00 PM
# 8410195  13973306    JJ422245  09/20/2025 07:08:00 PM
# 8410196  13973002    JJ422001  09/20/2025 03:55:00 PM
# 8410197  13972730    JJ421679  09/20/2025 08:20:00 AM
#
#                            Block  IUCR                Primary Type  \
# 0                023XX S TROY ST  1582  OFFENSE INVOLVING CHILDREN
# 1        039XX W WASHINGTON BLVD  2017                   NARCOTICS
# 2              015XX N DAMEN AVE  0326                     ROBBERY
# ...

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8410198 entries, 0 to 8410197
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  int64
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
# ...

# %% [markdown]
# <h1> <strong> QUESTIONS </strong> </h1>

# %% [markdown]
# <h2> 1. Which primary type of crime occurs most frequently? </h2>

# %%
primary_type_df = chicago['Primary Type']

# %%
primary_type_df
# Out:
# 0          OFFENSE INVOLVING CHILDREN
# 1                           NARCOTICS
# 2                             ROBBERY
# 3                 CRIM SEXUAL ASSAULT
# 4                     CRIMINAL DAMAGE
#                       ...
# 8410193           MOTOR VEHICLE THEFT
# 8410194           MOTOR VEHICLE THEFT
# 8410195                       ASSAULT
# 8410196                     NARCOTICS
# 8410197           MOTOR VEHICLE THEFT
# Name: Primary Type, Length: 8410198, dtype: object

# %%
primary_type_df.value_counts()
# Out:
# Primary Type
# THEFT                                1785150
# BATTERY                              1532491
# CRIMINAL DAMAGE                       956346
# NARCOTICS                             763342
# ASSAULT                               563123
# OTHER OFFENSE                         524325
# BURGLARY                              444757
# MOTOR VEHICLE THEFT                   429681
# DECEPTIVE PRACTICE                    387055
# ROBBERY                               314286
# CRIMINAL TRESPASS                     226310
# WEAPONS VIOLATION                     124642
# PROSTITUTION                           70405
# OFFENSE INVOLVING CHILDREN             60359
# PUBLIC PEACE VIOLATION                 54729
# SEX OFFENSE                            34126
# CRIM SEXUAL ASSAULT                    27290
# INTERFERENCE WITH PUBLIC OFFICER       20176
# LIQUOR LAW VIOLATION                   15377
# GAMBLING                               14663
# ...

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
primary_type_df.value_counts().plot(kind='bar')
plt.title("Number of Cases by Primary Crime Type")
plt.xlabel("Primary Crime Type")
plt.ylabel("Number of Cases")
plt.show()

# %% [markdown]
# <h2> INSIGHT 1 : Theft and Battery are the most common crimes, while Domestic Violence and Ritualism are the rarest. </h2> <HR>

# %% [markdown]
# <h2> 2. Are there specific districts with a higher proportion of robbery crimes? </h2>

# %%
robbery = chicago[chicago['Primary Type'] == 'ROBBERY']

# %%
robbery
# Out:
#                ID Case Number                    Date                   Block  \
# 2        12131221    JD327000  08/10/2020 09:45:00 AM       015XX N DAMEN AVE
# 8        12729745    JF279458  06/14/2022 02:47:00 PM     035XX N CENTRAL AVE
# 18        6255892    HP342049  05/17/2008 06:00:00 PM   101XX S LAFAYETTE AVE
# 19        6272641    HP358387  05/27/2008 01:00:00 AM       105XX S PERRY AVE
# 20        6438609    HP496499  08/05/2008 10:37:00 PM       126XX S UNION AVE
# ...           ...         ...                     ...                     ...
# 8409842  13972849    JJ421428  09/20/2025 06:15:00 AM     052XX N SHERIDAN RD
# 8409957  13973233    JJ422097  09/20/2025 04:40:00 PM       080XX S PEORIA ST
# 8409966  13972560    JJ421373  09/20/2025 02:59:00 AM   036XX W FRANKLIN BLVD
# 8410054  13973065    JJ421934  09/20/2025 02:00:00 PM    031XX W ROOSEVELT RD
# 8410144  13973114    JJ422089  09/20/2025 04:45:00 PM  059XX N CALIFORNIA AVE
#
# ...

# %%
robbery.groupby(['District']).size()
# Out:
# District
# 1.0      9361
# 2.0     17296
# 3.0     19159
# 4.0     18094
# 5.0     13245
# 6.0     23728
# 7.0     19991
# 8.0     21461
# 9.0     14974
# 10.0    15212
# 11.0    23260
# 12.0    15032
# 14.0    12764
# 15.0    14715
# 16.0     4345
# 17.0     7454
# 18.0    10418
# 19.0    11948
# 20.0     4223
# 22.0     9435
# 24.0     9648
# 25.0    18516
# 31.0        2
# dtype: int64

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
robbery.groupby(['District']).size().plot(kind='bar')
plt.title("Number of Robbery Cases per District")
plt.xlabel("District")
plt.ylabel("Number of Cases")
plt.show()

# %% [markdown]
# <H2> INSIGHT 2 : District 6 has the most robbery cases, followed by District 11. </H2> <hr>

# %% [markdown]
# <h2> 3. Is criminal sexual assault more frequent in 2023 compared to criminal damage? </h2>

# %%
year_2023 = chicago[chicago['Year'] == 2023]

# %%
year_2023
# Out:
#                ID Case Number                    Date  \
# 1        13053066    JG103252  01/03/2023 04:44:00 PM
# 4        13203321    JG415333  09/06/2023 05:00:00 PM
# 5        13204489    JG416325  09/06/2023 11:00:00 AM
# 10       13003649    JG177593  02/22/2023 01:50:00 PM
# 11       13061203    JG246126  05/03/2023 08:10:00 AM
# ...           ...         ...                     ...
# 8406458  13317972    JG553423  12/02/2023 02:02:00 AM
# 8406459  13329091    JH104918  12/29/2023 12:00:00 PM
# 8407435  13977459    JJ426749  07/01/2023 11:45:00 AM
# 8408433  13978606    JJ428657  02/01/2023 12:00:00 AM
# 8409526  13980865    JJ431396  12/11/2023 12:00:00 AM
#
#                            Block  IUCR                Primary Type  \
# 1        039XX W WASHINGTON BLVD  2017                   NARCOTICS
# 4               002XX N Wells st  1320             CRIMINAL DAMAGE
# 5                 0000X E 8TH ST  0810                       THEFT
# ...

# %%
sexual_assault = (year_2023['Primary Type'] == 'CRIMINAL SEXUAL ASSAULT').sum()

# %%
sexual_assault
# Out:
# np.int64(1668)

# %%
criminal_damage = (year_2023['Primary Type'] == 'CRIMINAL DAMAGE').sum()

# %%
criminal_damage
# Out:
# np.int64(30093)

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
csa_cd_2023 = chicago[(chicago['Year'] == 2023) & (chicago['Primary Type'].isin(['CRIMINAL SEXUAL ASSAULT','CRIMINAL DAMAGE']))].groupby('Primary Type').size()

csa_cd_2023.plot(kind='bar', title="Criminal Sexual Assault vs Criminal Damage (2023)")
# Out:
# <Axes: title={'center': 'Criminal Sexual Assault vs Criminal Damage (2023)'}, xlabel='Primary Type'>

# %% [markdown]
# <h2> INSIGHT 3 : Criminal Damage cases are higher than Criminal Sexual Assault cases in 2023. </h2> <hr>

# %% [markdown]
# <h2> 4. Which ward has the highest number of narcotics crimes? </h2>

# %%
narcotics = chicago[chicago['Primary Type'] == 'NARCOTICS']['Ward'].mode()[0]

# %%
narcotics
# Out:
# np.float64(28.0)

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
Narcotics = chicago[chicago['Primary Type'] == 'NARCOTICS']
narcotics_ward = Narcotics['Ward'].value_counts()

narcotics_ward.plot(kind='bar', figsize=(12,6), color='skyblue')

plt.title("Narcotics Crimes by Ward")
plt.xlabel("Ward")
plt.ylabel("Number of Narcotics Crimes")
plt.show()

# %% [markdown]
# <h2> INSIGHT 4 : Ward 28 has the most narcotics crimes. </h2> <hr>

# %% [markdown]
# <H2> 5. What community area has the most first-degree murder? </H2>

# %%
murder_area = chicago[chicago['Description'] == 'FIRST DEGREE MURDER'].groupby('Community Area').size()

# %%
murder_area
# Out:
# Community Area
# 1.0     130
# 2.0      74
# 3.0     110
# 4.0      22
# 5.0      20
#        ...
# 73.0    208
# 74.0      3
# 75.0    105
# 76.0      7
# 77.0     60
# Length: 77, dtype: int64

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
murder_area.plot(kind='bar', figsize=(12,6), color='crimson')

plt.title("First-Degree Murder Cases by Community Area")
plt.xlabel("Community Area")
plt.ylabel("Number of Cases")
plt.show()

# %% [markdown]
# <h2> INSIGHT 5 : The community area with the most first-degree murder cases is Community Area 25. </h2> <hr>

# %% [markdown]
# <h2> 6. What is the most common primary type of case occurring at a residence? </h2>

# %%
residence = chicago[chicago['Location Description'] == 'RESIDENCE']

# %%
residence
# Out:
#                ID Case Number                    Date  \
# 0        13311263    JG503434  07/29/2022 03:39:00 AM
# 6        11695116    JC272771  05/21/2019 08:20:00 AM
# 7        12419690    JE295655  07/07/2021 10:30:00 AM
# 18        6255892    HP342049  05/17/2008 06:00:00 PM
# 22       11662417    JC232642  04/21/2019 12:30:00 PM
# ...           ...         ...                     ...
# 8410171  13972752    JJ421614  09/20/2025 09:54:00 AM
# 8410172  13973057    JJ422096  09/20/2025 12:30:00 AM
# 8410180  13972654    JJ421486  09/20/2025 08:00:00 AM
# 8410182  13979951    JJ430249  09/20/2025 12:00:00 AM
# 8410189  13980272    JJ430808  09/20/2025 04:00:00 PM
#
#                                        Block  IUCR  \
# 0                            023XX S TROY ST  1582
# 6                     018XX S CALIFORNIA AVE  0620
# 7                      132XX S GREENWOOD AVE  1544
# 18                     101XX S LAFAYETTE AVE  031A
# 22                           009XX E 80TH ST  031A
# ...

# %%
residence['Primary Type'].mode()[0]
# Out:
# 'BATTERY'

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
chicago[chicago['Location Description']=='RESIDENCE']['Primary Type'].value_counts().plot(kind='bar', figsize=(10,5), title='Primary Types of Cases at Residences')
plt.xlabel('Primary Type')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <h2> INSIGHT 6 : The most common primary type of case occuring at residence is Battery. </h2> <hr>

# %% [markdown]
# <H2>7. Which ward has the most beats? </H2>

# %%
chicago.groupby('Ward')['Beat'].sum()
# Out:
# Ward
# 1.0     209286227
# 2.0     230955958
# 3.0     105176648
# 4.0     132238527
# 5.0      85037786
# 6.0     151135367
# 7.0      87012419
# 8.0     104701743
# 9.0     117453230
# 10.0     58354556
# 11.0     99371510
# 12.0     89811761
# 13.0     78021026
# 14.0     90803587
# 15.0    154523116
# 16.0    180499436
# 17.0    177536139
# 18.0    101190947
# 19.0    154301891
# 20.0    116067908
# 21.0    307254139
# 22.0     93066520
# 23.0     79597278
# 24.0    327934327
# 25.0    134615518
# 26.0    212142200
# 27.0    406540761
# 28.0    443795758
# 29.0    330110222
# 30.0    239273286
# 31.0    261980185
# 32.0    212203997
# 33.0    133650828
# 34.0    246388823
# 35.0    169515798
# 36.0    184214796
# 37.0    412959823
# 38.0    131658108
# 39.0    126095071
# 40.0    179368386
# 41.0    136021198
# 42.0    348514819
# 43.0    181322821
# 44.0    224307460
# 45.0    131314352
# 46.0    226846545
# 47.0    157189375
# 48.0    172296101
# 49.0    275306445
# ...

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
chicago.groupby('Ward')['Beat'].sum().plot(kind='bar', color='pink',figsize=(10,5), title='Total Beats per Ward')
plt.xlabel('Ward')
plt.ylabel('Number of Beats')
plt.show()

# %% [markdown]
# <h2> INSIGHT 7 : Ward 28 has the most beats (443795758). </h2> <hr>

# %% [markdown]
# <h2> 8. Between Burglary and Sex Offense, which primary type of case was the most common in residences during 2008? </h2>

# %%
res_2008 = chicago[(chicago['Location Description'] == 'RESIDENCE') & (chicago['Year'] == 2008)]

# %%
res_2008
# Out:
#                ID Case Number                    Date                  Block  \
# 18        6255892    HP342049  05/17/2008 06:00:00 PM  101XX S LAFAYETTE AVE
# 6494      6659785    HP732219  12/13/2008 04:03:00 PM       001XX W 112TH ST
# 12652     6229465    HP316031  05/04/2008 01:30:00 AM    108XX S CALUMET AVE
# 20434    13355041    JH135918  01/01/2008 12:00:00 AM    009XX N LATROBE AVE
# 22914     6071295    HP171102  02/11/2008 11:30:00 PM   076XX S EAST END AVE
# ...           ...         ...                     ...                    ...
# 8394174   9353232    HW496177  01/01/2008 08:00:00 AM        039XX W 83RD ST
# 8394779   9388440    HW530546  01/01/2008 08:00:00 AM    027XX N MELVINA AVE
# 8397199   9516319    HX171880  01/01/2008 08:00:00 AM      029XX S LOOMIS ST
# 8404769   9949650    HY138341  08/02/2008 12:00:00 AM    022XX N KOSTNER AVE
# 8405393   9982390    HY172187  05/12/2008 12:00:00 AM        026XX W 55TH ST
#
#          IUCR                Primary Type  \
# ...

# %%
res_2008_cases = res_2008[res_2008['Primary Type'].isin(['BURGLARY', 'SEX OFFENSE'])]

# %%
res_2008_cases
# Out:
#                ID Case Number                    Date                 Block  \
# 38828     6501176    HP575084  09/16/2008 09:00:00 AM     084XX S MORGAN ST
# 59043     6232447    HP319486  05/06/2008 05:19:00 AM   112XX S ABERDEEN ST
# 87372    12602247    JF124920  01/01/2008 12:00:00 AM    061XX S KARLOV AVE
# 91584     6048760    HP149642  01/29/2008 06:15:00 AM   120XX S ASHLAND AVE
# 91821     6684195    HP756446  12/29/2008 09:00:00 AM   082XX W BELMONT AVE
# ...           ...         ...                     ...                   ...
# 7004895  12062017    JD245802  01/01/2008 12:01:00 AM  048XX W ARMITAGE AVE
# 7217337  12216819    JD426407  07/23/2008 12:00:00 AM       004XX W 70TH ST
# 7276611  12605897    JF129474  03/07/2008 12:00:00 AM       081XX S WOOD ST
# 7444048  12795204    JF358059  09/30/2008 08:00:00 AM   052XX S RICHMOND ST
# 7656778  13147765    JG349711  02/15/2008 12:00:00 AM    050XX S SEELEY AVE
#
# ...

# %%
b_or_so = res_2008_cases['Primary Type'].value_counts()

# %%
b_or_so
# Out:
# Primary Type
# BURGLARY       9485
# SEX OFFENSE     385
# Name: count, dtype: int64

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
b_or_so.plot(kind='bar', color=['skyblue', 'salmon'], figsize=(6,4), title='Burglary vs Sex Offense in Residences (2008)')
plt.xlabel('Primary Type')
plt.ylabel('Number of Cases')
plt.show()

# %% [markdown]
# <h2> INSIGHT 8 : Burglary had the most cases in residences during 2008 compared to Sex Offense. </h2> <hr>

# %% [markdown]
# <h2> 9. Is there a correlation between Beat and District?</h2>

# %%
chicago['Beat'].corr(chicago['District'])
# Out:
# np.float64(0.950493801987207)

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
chicago.plot.scatter(x='Beat', y='District', figsize=(8,5), color='teal', title='Correlation between Beat and District')
# Out:
# <Axes: title={'center': 'Correlation between Beat and District'}, xlabel='Beat', ylabel='District'>

# %% [markdown]
# <h2> INSIGHT 9 : Beat and District have a strong positive correlation (0.95), which means that higher beats generally correspond to higher districts.</h2> <hr>

# %% [markdown]
# <h2> 10. What is the average number of beats involved in prostitution? </h2>

# %%
prostitution = chicago[chicago['Primary Type'] == 'PROSTITUTION']

# %%
prostitution
# Out:
#                ID Case Number                    Date                  Block  \
# 92       13208678    JG412891  09/01/2023 01:30:00 AM    047XX S KEATING AVE
# 96       13208668    JG406226  09/01/2023 02:10:00 AM        047XX W 47TH ST
# 1627     13208710    JG406266  09/01/2023 03:30:00 AM        047XX W 49TH ST
# 4507     13207140    JG420184  09/11/2023 03:20:00 PM        034XX W 63RD ST
# 5583     13208719    JG421890  09/12/2023 09:00:00 PM     061XX S JUSTINE ST
# ...           ...         ...                     ...                    ...
# 8407416  13970210    JJ418557  09/17/2025 10:08:00 PM     047XX N PULASKI RD
# 8408357  13971306    JJ419824  09/18/2025 08:42:00 PM    030XX S SHIELDS AVE
# 8408691  13972380    JJ421164  09/19/2025 10:40:00 PM   039XX W LAWRENCE AVE
# 8408794  13972326    JJ421082  09/19/2025 08:42:00 PM  044XX N MILWAUKEE AVE
# 8409090  13972368    JJ421150  09/19/2025 10:25:00 PM     048XX N BERNARD ST
#
# ...

# %%
prostitution['Beat'].mean()
# Out:
# np.float64(1254.8237341097933)

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
chicago[chicago['Primary Type']=='PROSTITUTION']['Beat'].plot.hist(
    bins=10, figsize=(8,5), color='tan', edgecolor='black', title='Beats in Prostitution Cases'
)
plt.xlabel('Beat')
plt.ylabel('Number of Cases')
plt.show()

# %% [markdown]
# <h2> INSIGHT 10 : The average beats in prostitution case is 1254.82. </h2> <hr>

# %% [markdown]
# <h2> 11. What are the latitude and longitude coordinates of the district with the most Child Pornography cases? </h2

# %%
cp = chicago[chicago['Description'] == 'CHILD PORNOGRAPHY']

# %%
cp
# Out:
#                ID Case Number                    Date                  Block  \
# 0        13311263    JG503434  07/29/2022 03:39:00 AM        023XX S TROY ST
# 915      13160405    JG364451  07/08/2023 12:13:00 PM     005XX W MADISON ST
# 2018     12523398    JE423596  07/19/2021 12:00:00 AM        023XX W 24TH PL
# 3475     13342244    JH120595  07/10/2023 04:01:00 PM   052XX W BERENICE AVE
# 3593     13207284    JG420012  09/10/2023 11:00:00 PM       035XX N NORA AVE
# ...           ...         ...                     ...                    ...
# 8166399  13961127    JJ407548  04/27/2025 12:00:00 AM        041XX W 82ND PL
# 8168040  13963802    JJ410868  07/30/2025 12:00:00 AM   017XX W MARQUETTE RD
# 8169866  13844674    JJ264931  03/31/2025 08:00:00 AM     034XX W PARKER AVE
# 8406210  13967949    JJ415642  09/15/2025 05:02:00 PM  017XX N MILWAUKEE AVE
# 8408725  13979888    JJ429058  06/22/2024 05:34:00 PM   027XX N MULLIGAN AVE
#
# ...

# %%
cp_district = cp['District'].value_counts()

# %%
cp_district
# Out:
# District
# 12.0    257
# 9.0     160
# 25.0    136
# 8.0     126
# 16.0    109
# 10.0     84
# 22.0     79
# 4.0      75
# 17.0     74
# 19.0     70
# 2.0      69
# 3.0      59
# 24.0     59
# 14.0     53
# 11.0     52
# 6.0      49
# 15.0     49
# 7.0      48
# 1.0      46
# 5.0      43
# 20.0     39
# 18.0     34
# 31.0      2
# Name: count, dtype: int64

# %%
top_cp_district = cp_district.index[0]

# %%
top_cp_district
# Out:
# np.float64(12.0)

# %%
coordinates = chicago[chicago['District'] == top_cp_district][['Latitude', 'Longitude']].dropna().head(1)

# %%
coordinates
# Out:
#      Latitude  Longitude
# 29  41.899206 -87.705506

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
plt.scatter(coordinates['Longitude'], coordinates['Latitude'], color='red', alpha=0.6)
plt.title('District 12 - Child Pornography Cases')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# <h2> INSIGHT 11 : District 12 has the highest number of Child Pornography cases (257). </h2>
# <h2> INSIGHT 12 : The cases are concentrated around coordinates Latitude 41.899206, Longitude -87.705506. </h2> <HR> </HR>

# %% [markdown]
# <H2> 12. Which community area has the most weapons violation cases occurring on sidewalks? </H2>

# %%
weapons_sidewalk = chicago[(chicago['Primary Type'] == 'WEAPONS VIOLATION') & (chicago['Location Description'] == 'SIDEWALK')]

# %%
weapons_sidewalk
# Out:
#                ID Case Number                    Date                  Block  \
# 47       13424244    JH219128  04/09/2024 09:54:00 PM  064XX S CLAREMONT AVE
# 507      13201769    JG413721  09/06/2023 01:30:00 PM  060XX N MILWAUKEE AVE
# 988      13203265    JG415310  09/07/2023 05:40:00 PM  110XX S WENTWORTH AVE
# 1524     13203362    JG415511  09/07/2023 08:19:00 PM    0000X E ILLINOIS ST
# 1958     13204563    JG416911  09/08/2023 09:45:00 PM        027XX W 19TH ST
# ...           ...         ...                     ...                    ...
# 8408831  13971388    JJ420009  09/19/2025 01:31:00 AM      062XX S THROOP ST
# 8408957  13972394    JJ421232  09/19/2025 11:23:00 PM        027XX W 55TH ST
# 8408962  13971910    JJ420646  09/19/2025 02:59:00 PM  055XX S PRINCETON AVE
# 8409847  13973375    JJ422329  09/20/2025 09:25:00 PM       037XX S STATE ST
# 8409854  13973394    JJ422387  09/20/2025 10:42:00 PM    029XX N KENOSHA AVE
#
# ...

# %%
community_area = weapons_sidewalk['Community Area'].value_counts()

# %%
community_area
# Out:
# Community Area
# 25.0    1683
# 29.0    1039
# 67.0    1000
# 43.0     811
# 23.0     806
#         ...
# 72.0      14
# 10.0       6
# 74.0       6
# 12.0       3
# 76.0       2
# Name: count, Length: 76, dtype: int64

# %%
top_community = community_area.index[0]

# %%
top_community
# Out:
# np.float64(25.0)

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
community_area.plot(kind='bar', figsize=(20,5), color='orange', title='Weapons Violation on Sidewalks by Community Area')
plt.xlabel('Community Area')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <h2> INSIGHT 13 : District 25 has the highest number of weapons violation cases occurring on sidewalks. </h2> <hr>

# %% [markdown]
# <h2> 13. How has the number of Theft cases changed from 2022 to 2023? </h2>

# %%
theft_cases = chicago[(chicago['Primary Type'] == 'THEFT') & (chicago['Year'].isin([2022, 2023]))]

# %%
theft_cases
# Out:
#                ID Case Number                    Date                  Block  \
# 5        13204489    JG416325  09/06/2023 11:00:00 AM         0000X E 8TH ST
# 50       13179181    JG386523  08/17/2023 03:15:00 PM  020XX N MILWAUKEE AVE
# 51       13179344    JG386917  08/17/2023 07:25:00 PM   030XX N ELBRIDGE AVE
# 53       13181885    JG389920  08/20/2023 06:00:00 AM   020XX N LECLAIRE AVE
# 56       13184491    JG393031  08/22/2023 11:44:00 AM     026XX N ELSTON AVE
# ...           ...         ...                     ...                    ...
# 8145402  13247858    JG468757  10/17/2023 08:00:00 PM  036XX N RECREATION DR
# 8149254  13936366    JJ377380  09/01/2023 12:01:00 AM       010XX W 111TH ST
# 8151104  12891403    JF472893  11/12/2022 04:00:00 PM     050XX S LAWLER AVE
# 8162892  13957356    JJ402942  08/01/2023 12:00:00 AM       083XX S GREEN ST
# 8170903  13969143    JJ417221  08/01/2023 12:00:00 AM        038XX W 67TH PL
#
# ...

# %%
theft_cases.groupby('Year').size()
# Out:
# Year
# 2022    54899
# 2023    57492
# dtype: int64

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
theft_counts = chicago[(chicago['Primary Type']=='THEFT') & (chicago['Year'].isin([2022,2023]))].groupby('Year').size()
plt.plot(theft_counts.index, theft_counts.values, marker='o', color='blue')
plt.title('Theft Cases: 2022 vs 2023')
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.xticks([2022, 2023])
plt.grid(True)
plt.show()

# %% [markdown]
# <h2> INSIGHT 14 : There were 54,899 theft cases in 2022. </h2>
# <h2> INSIGHT 15 : There were 57,492 theft cases in 2023. </h2>
# <h2> INSIGHT 16 : Theft cases increased by 2,593 cases from 2022 to 2023. </h2> <HR></HR>

# %% [markdown]
# <H2> 14. What are the X and Y coordinates of the ward with the highest number of Stalking cases? </H2>

# %%
stalking = chicago[chicago['Primary Type'] == 'STALKING']

# %%
stalking
# Out:
#                ID Case Number                    Date  \
# 44       13124701    JG321999  06/30/2023 04:00:00 AM
# 160      13201686    JG413607  09/06/2023 01:40:00 PM
# 208      13203927    JG415989  09/07/2023 12:00:00 AM
# 782      13208573    JG421611  08/25/2023 03:00:00 PM
# 956      13272505    JG498651  11/10/2023 06:30:00 AM
# ...           ...         ...                     ...
# 8408771  13972844    JJ421737  09/19/2025 10:30:00 AM
# 8409109  13975116    JJ424546  09/19/2025 07:52:00 AM
# 8409501  13972916    JJ421689  09/20/2025 11:23:00 AM
# 8409527  13978956    JJ429112  09/09/2025 12:00:00 PM
# 8409690  13972843    JJ421704  09/20/2025 09:53:00 AM
#
#                                        Block  IUCR Primary Type  \
# 44                          007XX E 111TH ST  0583     STALKING
# 160                      111XX S LANGLEY AVE  0580     STALKING
# 208                      078XX S CRANDON AVE  0580     STALKING
# ...

# %%
ward_stalking = stalking['Ward'].value_counts()

# %%
ward_stalking
# Out:
# Ward
# 42.0    224
# 27.0    223
# 6.0     221
# 8.0     220
# 3.0     200
# 17.0    194
# 24.0    193
# 20.0    183
# 9.0     183
# 28.0    173
# 2.0     172
# 21.0    171
# 5.0     170
# 7.0     164
# 4.0     161
# 34.0    128
# 25.0    125
# 10.0    123
# 16.0    105
# 18.0    104
# 1.0     103
# 37.0    102
# 49.0     99
# 15.0     97
# 29.0     95
# 45.0     91
# 26.0     91
# 19.0     89
# 44.0     86
# 11.0     84
# 35.0     83
# 41.0     82
# 47.0     80
# 31.0     80
# 30.0     78
# 14.0     77
# 38.0     77
# 23.0     76
# 13.0     76
# 48.0     76
# 22.0     75
# 32.0     75
# 40.0     75
# 46.0     74
# 33.0     73
# 12.0     72
# 43.0     63
# 36.0     63
# 39.0     62
# 50.0     61
# Name: count, dtype: int64

# %%
top_ward = ward_stalking.index[0]

# %%
top_ward
# Out:
# np.float64(42.0)

# %%
x_y_coordinates = chicago[chicago['Ward'] == top_ward][['X Coordinate', 'Y Coordinate']].dropna().head(1)

# %%
x_y_coordinates
# Out:
#    X Coordinate  Y Coordinate
# 4     1174694.0     1901831.0

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
x_y_coordinates.plot.scatter(['X Coordinate'], ['Y Coordinate'], color ='red', alpha=0.6)
plt.title('Stalking Cases in Top Ward'); plt.xlabel('X'); plt.ylabel('Y'); plt.show()

# %% [markdown]
# <h2> INSIGHT 17 : Ward 42 has the most Stalking cases. </h2>
# <H2> INSIGHT 18 : Cases are near X: 1174694, Y: 1901831.</H2> <HR></HR>

# %% [markdown]
# <H2> 15. How does the total number of Motor Vehicle Theft cases in District 1 compare to District 3 during 2008? </H2>

# %%
mvt = chicago[(chicago['Primary Type'] == 'MOTOR VEHICLE THEFT') & (chicago['Year'] == 2008) & (chicago['District'].isin([1, 3]))]

# %%
mvt
# Out:
#               ID Case Number                    Date                 Block  \
# 3181624  6114768    HP209266  03/04/2008 02:00:00 PM  007XX S FINANCIAL PL
# 3181912  6079325    HP176111  02/14/2008 10:13:00 PM       014XX E 67TH PL
# 3182093  6091024    HP188592  02/15/2008 02:00:00 PM  070XX S MICHIGAN AVE
# 3183641  6162795    HP252962  03/31/2008 01:00:00 AM  069XX S MICHIGAN AVE
# 3184105  6142019    HP233527  03/19/2008 06:30:00 AM  025XX S MICHIGAN AVE
# ...          ...         ...                     ...                   ...
# 3717133  6631735    HP703863  11/26/2008 11:00:00 AM     002XX S WACKER DR
# 3772362  6915904    HP726632  12/10/2008 03:07:00 PM  0000X W CULLERTON ST
# 3877420  7230616    HR643395  02/18/2008 04:00:00 PM    020XX S WABASH AVE
# 3905054  7209255    HR623945  10/26/2008 06:00:00 AM   072XX S CRANDON AVE
# 4178434  7546851    HP655575  10/30/2008 06:30:00 AM       018XX E 72ND ST
#
# ...

# %%
mvt.groupby('District').size()
# Out:
# District
# 1.0    397
# 3.0    937
# dtype: int64

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
mvt.groupby('District').size().plot(kind='bar', color=['blue','orange'], figsize=(6,4), title='Motor Vehicle Theft in District 1 vs 3 (2008)')
plt.xlabel('District')
plt.ylabel('Number of Cases')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <h2> INSIGHT 19 : District 3 had the highest number of Motor Vehicle Theft cases in 2008, with 937 cases. </h2>
# <h2> INSIGHT 20 : District 1 had fewer cases, with 397 cases. </h2>
# <h2> INSIGHT 21 : District 3 had over twice as many Motor Vehicle Theft cases as District 1. </h2> <hr>

# %% [markdown]
# <h2> 16. Are there more arrests in Deceptive Practice cases than in Assault cases? </h2>

# %%
cases = chicago[chicago['Primary Type'].isin(['DECEPTIVE PRACTICE', 'ASSAULT'])]

# %%
cases
# Out:
#                ID Case Number                    Date  \
# 41       13121127    JG313964  06/22/2023 06:52:00 PM
# 55       13183567    JG392073  08/21/2023 02:37:00 PM
# 82       13200930    JG412695  09/05/2023 07:22:00 PM
# 86       13340773    JH118602  12/11/2023 02:15:00 PM
# 88       13340598    JH118606  07/01/2023 09:00:00 AM
# ...           ...         ...                     ...
# 8410179  13973287    JJ422186  09/20/2025 02:55:00 PM
# 8410181  13973174    JJ422113  09/20/2025 05:03:00 PM
# 8410185  13979259    JJ429508  09/10/2025 04:45:00 PM
# 8410187  13977474    JJ426700  09/20/2025 12:15:00 AM
# 8410195  13973306    JJ422245  09/20/2025 07:08:00 PM
#
#                                 Block  IUCR        Primary Type  \
# 41                  015XX W NORTH AVE  1153  DECEPTIVE PRACTICE
# 55             022XX N LEAMINGTON AVE  1220  DECEPTIVE PRACTICE
# 82                 021XX N AUSTIN AVE  0520             ASSAULT
# ...

# %%
arrest = cases[cases['Arrest'] == True].groupby('Primary Type').size()

# %%
arrest
# Out:
# Primary Type
# ASSAULT               113956
# DECEPTIVE PRACTICE     47796
# dtype: int64

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
arrest.plot(kind='bar', color=['slategray','cadetblue'], figsize=(6,4), title='Number of Arrests: Deceptive Practice vs Assault')
plt.xlabel('Primary Type')
plt.ylabel('Number of Arrests')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <h2> INSIGHT 22 : In 2008, Assault resulted in 113,956 arrests. </h2>
# <H2> INSIGHT 23 : While, Deceptive Practice resulted in 47,796 arrests. </H2>
# <h2> INSIGHT 24 : Arrests for Assault were over twice those for Deceptive Practice, indicating a higher rate of arrests for violent crimes that year.</h2> <HR> </HR>

# %% [markdown]
# <H2> 17. Are there more domestic cases recorded in Apartments or on Streets? </H2>

# %%
locations = chicago[chicago['Location Description'].isin(['APARTMENT', 'STREET'])]

# %%
locations
# Out:
#                ID Case Number                    Date                 Block  \
# 2        12131221    JD327000  08/10/2020 09:45:00 AM     015XX N DAMEN AVE
# 11       13061203    JG246126  05/03/2023 08:10:00 AM   073XX S EMERALD AVE
# 13       13116982    JG312117  06/23/2023 04:44:00 AM       040XX W 59TH ST
# 17          27547    JH119907  06/05/2023 09:15:00 PM   020XX N KIMBALL AVE
# 19        6272641    HP358387  05/27/2008 01:00:00 AM     105XX S PERRY AVE
# ...           ...         ...                     ...                   ...
# 8410192  13975177    JJ424627  09/20/2025 10:00:00 AM   040XX W HARRISON ST
# 8410193  13973682    JJ422722  09/20/2025 09:30:00 PM  060XX N ARTESIAN AVE
# 8410194  13973492    JJ422488  09/20/2025 11:30:00 PM     004XX N PEORIA ST
# 8410195  13973306    JJ422245  09/20/2025 07:08:00 PM   107XX S PRAIRIE AVE
# 8410197  13972730    JJ421679  09/20/2025 08:20:00 AM    087XX S BURLEY AVE
#
# ...

# %%
domestic = locations[locations['Domestic'] == True].groupby('Location Description').size()

# %%
domestic
# Out:
# Location Description
# APARTMENT    469727
# STREET       179492
# dtype: int64

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
domestic.plot(kind='pie', autopct='%1.1f%%', colors=['olive','olivedrab'], title='Domestic Cases: Apartment vs Street')
plt.ylabel('')
plt.show()

# %% [markdown]
# <h2> INSIGHT 25 : Apartments had 469,727 domestic cases. </h2>
# <H2> INSIGHT 26 : And Streets had 179,492 cases.</H2>
# <h2> INSIGHT 27 : Domestic cases are much higher in Apartments than on Streets. </h2> <HR></HR>

# %% [markdown]
# <H2> 18. What is the average occurrence of domestic involvement in Homicide cases during 2006? </H2>

# %%
homicide_2006 = chicago[(chicago['Primary Type'] == 'HOMICIDE') & (chicago['Year'] == 2006)]

# %%
homicide_2006
# Out:
#               ID Case Number                    Date  \
# 98428       3656    HM435696  06/25/2006 07:56:00 AM
# 99335       3524    HM232296  03/14/2006 07:29:00 PM
# 99400       3688    HM468496  07/11/2006 03:00:00 PM
# 99544       3643    HM419129  06/17/2006 02:00:00 AM
# 100345      3802    HM617429  09/23/2006 12:30:00 AM
# ...          ...         ...                     ...
# 2733108  5097907    HM700082  11/03/2006 06:01:00 PM
# 2776916  5032322    HM621190  09/25/2006 01:30:00 AM
# 7738375     3495    HM176257  02/11/2006 06:30:00 PM
# 7815381    28439    HM409539  06/12/2006 03:40:00 PM
# 7815567    28440    HM409539  06/12/2006 03:40:00 PM
#
#                                        Block  IUCR Primary Type  \
# 98428                     003XX S WHIPPLE ST  0110     HOMICIDE
# 99335    050XX S DR MARTIN LUTHER KING JR DR  0110     HOMICIDE
# 99400                   006XX N RIDGEWAY AVE  0110     HOMICIDE
# 99544                        006XX W 89TH ST  0110     HOMICIDE
# ...

# %%
domestic_homicide = homicide_2006['Domestic'].value_counts()

# %%
domestic_homicide
# Out:
# Domestic
# False    457
# True      21
# Name: count, dtype: int64

# %%
homicide_2006['Domestic'].mean()
# Out:
# np.float64(0.043933054393305436)

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
domestic_homicide .plot(kind='bar', color=['salmon','skyblue'], figsize=(6,4), title='Domestic vs Non-Domestic Homicide Cases (2006)')
plt.xlabel('Domestic')
plt.ylabel('Number of Cases')
plt.show()

# %% [markdown]
# <h2> INSIGHT 28 : In 2006, most Homicide cases (457 out of 478) were non-domestic. </h2>
# <H2> INSIGHT 29 : And only 21 cases involved domestic incidents. </h2>
# <h2> INSIGHT 30 : The average domestic involvement in Homicide cases (2006) is 0.04.</h2> <HR></HR>

# %% [markdown]
# <h2> 19. Is criminal trespass more frequent in ward 15 compared to kidnapping? </h2>

# %%
ward15 = chicago[(chicago['Ward'] == 15) & (chicago['Primary Type'].isin(['CRIMINAL TRESPASS', 'KIDNAPPING']))]

# %%
ward15
# Out:
#                ID Case Number                    Date                   Block  \
# 12392    13216856    JG431830  09/20/2023 01:30:00 PM     045XX S WESTERN AVE
# 15038    13219886    JG435383  09/23/2023 03:10:00 AM       062XX S MOZART ST
# 20767    13229029    JG446092  10/01/2023 12:00:00 AM     045XX S WESTERN AVE
# 20889    13228076    JG444856  09/30/2023 10:28:00 AM      063XX S ALBANY AVE
# 22449    13231931    JG449769  10/03/2023 12:00:00 AM      066XX S WHIPPLE ST
# ...           ...         ...                     ...                     ...
# 8392492   9251158    HW396562  08/01/2013 06:00:00 PM  062XX S SACRAMENTO AVE
# 8393492   9309099    HW453840  09/16/2013 07:20:00 AM  066XX S CALIFORNIA AVE
# 8400678   9713906    HX364154  07/28/2014 03:30:00 PM         035XX W 63RD ST
# 8405149   9970317    HY160127  02/22/2015 01:50:00 PM         018XX W 66TH ST
# 8405352   9980610    HY170250  03/03/2015 10:20:00 AM       056XX S DAMEN AVE
#
# ...

# %%
ward15.groupby('Primary Type').size()
# Out:
# Primary Type
# CRIMINAL TRESPASS    3851
# KIDNAPPING            182
# dtype: int64

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
ward15.groupby('Primary Type').size().plot(kind='pie', autopct='%1.1f%%', colors=['sienna','maroon'], title='Criminal Trespass vs Kidnapping in Ward 15')
plt.ylabel('')
plt.show()

# %% [markdown]
# <h2> INSIGHT 31 : Criminal Trespass in Ward 15 had 3,851 cases. </h2>
# <H2> INSIGHT 32 : Kidnapping in Ward 15 had 182 cases. </H2>
# <H2> INSIGHT 33 : Criminal Trespass occurs far more frequently than Kidnapping in Ward 15. </H2> <HR></HR>

# %% [markdown]
# <H2> 20. What is the total number of cases for all primary types between 2001 and 2023? </H2>

# %%
cases_2001_2023 = chicago[(chicago['Year'] >= 2001) & (chicago['Year'] <= 2023)]

# %%
cases_2001_2023
# Out:
#                ID Case Number                    Date  \
# 0        13311263    JG503434  07/29/2022 03:39:00 AM
# 1        13053066    JG103252  01/03/2023 04:44:00 PM
# 2        12131221    JD327000  08/10/2020 09:45:00 AM
# 3        11227634    JB147599  08/26/2017 10:00:00 AM
# 4        13203321    JG415333  09/06/2023 05:00:00 PM
# ...           ...         ...                     ...
# 8409493  13980488    JJ430606  09/27/2020 12:55:00 PM
# 8409526  13980865    JJ431396  12/11/2023 12:00:00 AM
# 8409651  13980473    JJ430518  01/01/2020 06:20:00 PM
# 8409914  13980479    JJ430485  03/07/2021 12:35:00 PM
# 8410082  13980134    JJ430531  12/06/2021 12:01:00 AM
#
#                            Block  IUCR                Primary Type  \
# 0                023XX S TROY ST  1582  OFFENSE INVOLVING CHILDREN
# 1        039XX W WASHINGTON BLVD  2017                   NARCOTICS
# 2              015XX N DAMEN AVE  0326                     ROBBERY
# ...

# %%
total_cases = cases_2001_2023['Primary Type'].count()

# %%
total_cases
# Out:
# np.int64(7979860)

# %%
yearly_counts = cases_2001_2023.groupby('Year')['Primary Type'].count()

# %%
yearly_counts
# Out:
# Year
# 2001    485954
# 2002    486830
# 2003    475996
# 2004    469439
# 2005    453785
# 2006    448198
# 2007    437105
# 2008    427211
# 2009    392859
# 2010    370555
# 2011    352039
# 2012    336367
# 2013    307603
# 2014    275866
# 2015    264867
# 2016    269930
# 2017    269259
# 2018    269105
# 2019    261648
# 2020    212643
# 2021    209571
# 2022    239911
# 2023    263119
# Name: Primary Type, dtype: int64

# %% [markdown]
# <h2> <strong> Data Visualization  </strong> </h2>

# %%
yearly_counts.plot(kind='line', marker='o', color='blue', title='Total Cases per Year (2001-2023)')
plt.xlabel('Year')
plt.ylabel('Number of Cases')
plt.grid(True)
plt.show()

# %% [markdown]
# <h2> INSIGHT 34 : The total number of cases from 2001 to 2023 is 7,979,860, showing the overall volume of reported incidents during this period.</h2>
# <H2> INSIGHT 35 : Crime cases declined steadily from 2001 to 2020, indicating an overall reduction in reported incidents, but there is a slight increase in 2023. </H2> <HR> </HR>
